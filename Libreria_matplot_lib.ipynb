# %% [markdown]
# <a href="https://colab.research.google.com/github/vichacker1234/Proyectos_IA/blob/main/Libreria_matplot_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Librería Matbplotlib
# A continuación se va a mostrar como usar la librería Matplotlib en python

# %%
import matplotlib as mlp
from math import sqrt
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
from scipy.stats import kde
import seaborn as sns
import pandas as pd

# %% [markdown]
# #Ahora se va a analizar algunos aspectos gráficos de python

# %%
#Inicia en 0 finaliza en 9 con 200 muestras
x = np.linspace(0, 10, 200)
plt.plot(x,x**3)
plt.plot(x, 100*np.cos(x))

# %% [markdown]
# Se pueden especificar las características de las curvas trazadas, tales como el color, tipo de linea entre otras características. A continuación se presentan algunos ejemplos

# %%
x = np.linspace(0, 9, 100)

plt.plot(x, x**2*np.cos(x),color='lightgreen',marker='>')
plt.plot(x, 100*np.cos(x), '--',color='r')
plt.show()

# %% [markdown]
# Ahora vamos a guardar la imágen que hemos obtenido

# %%
#Se crea una malla que empieza en 0 y termina en 9
#Esta tiene 100 puntos de muestra
x = np.linspace(0, 9, 100)
#Mostramos el tamaño de la imágen 
fig=plt.figure() 
#Se crean curvas con plt.plot
plt.plot(x, x**2*np.cos(x),color='c',marker='>')
plt.plot(x, 100*np.cos(x), '--',color='r')
plt.show()

# Guardar imagen
fig.savefig('figura1.png')  #Podemos mofificar .png por .jpg, .jpeg

# %% [markdown]
# Ahora vamos a verificar que se haya guardado la imágen

# %%
# Verificar imagen se haya guardado
# !ls -lh figura1.png
# Out:
# -rw-r--r-- 1 root root 15K Apr 16 16:31 figura1.png

# %% [markdown]
# #En este punto se va a verificar que las imágenes se hayan guardado

# %%
#Para la primera imágen se usa Image
Image('figura1.png')

# %% [markdown]
# #Ahora se va a usar subplots

# %%
#Se usa una malla de 0 a 10 con 100 puntos de muestra
x = np.linspace(0, 10, 100)
#Se grafica la función f(x)=x^3 de color rojo
plt.plot(x, x**3,color="red")
#Se muestra la gráfica

plt.show()
#Se grafica la función 100cos(x) de color naranja
plt.plot(x, 100*np.cos(x),color="orange")
#Se usa plt.show para mostrar cada gráfico aparte
plt.show()

# %% [markdown]
# Ahora se porpone los gráficos de una manera diferente

# %%
plt.figure()  # crea un diagrama de gráficos 
#Se usa subplot para hacer varios gráficos a la  vez
plt.subplot(2, 1, 1) # (filas, columnas, número de panel)
plt.plot(x, x**3,color="red")
plt.subplot(2, 1, 2)
plt.plot(x, 100*np.cos(x),color="orange");

# %% [markdown]
# En este punto se van a analizar otros gráficos

# %%
plt.subplot(121)

# Subplot polar
plt.subplot(121, projection='polar')

# Fondo de color (En este acaso azul)
plt.subplot(122, facecolor='blue')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %% [markdown]
# **Insertar figuras en otras**
# Bastante similar a los subplots pero que permite introducir imágenes en otras

# %%
#Se define la mallla como siempre
x = np.linspace(4, 10, 70)
y = (x+7) ** 5
#Crear una figura nueva o activar una figura existente
fig = plt.figure() 

# fig.add_axes: ejes nuevos [izquierda, abajo, ancho, alto]
#Aquí se proponen los ejes en función de las coordendas puestas en la malla x
#los parámetros en el corchete permite definir el tamaño de ambos ejes
#En este caso la posición izquierda, abajo, ancho y alto.
axes1 = fig.add_axes([4.1, 0.1, 0.8, 0.8]) # main axes (Eje principal)
axes2 = fig.add_axes([4.2, 0.6, 0.3, 0.2]) # inset axes (Eje secundario)

# Figura grande
axes1.plot(x+2, y, 'y')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('Imagen grande')
plt.grid(True)

# Figura insertada
axes2.plot(y, x+5, 'r')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('Imagen pequeña');

# %% [markdown]
# **Títulos leyendas y etiquetas**
# Los títulos (titles) son el nombre que tienen los gráficos, las etiquetas (labels) son los nombres de los ejes y las leyendas (legends) son para guiarse cuando tenemos más de una trazado en el gráfico y se quieren diferenciarlas.

# %%
# Titulo y etiquetas
x = np.linspace(0, 10, 100)
#Función seno de numpy
y=np.sin(x)

plt.plot(x,y)
plt.xlabel('Valores en x')
plt.ylabel('valores en y')

#Ahora se define el título 
plt.title('Sen(x) entre 0 y 10')
plt.show()

# %% [markdown]
# ##Siguiendo con los títulos

# %%
# Titulo y etiquetas
fig, ax = plt.subplots()
ax.plot(range(10),label="h")
ax.plot(range(5),label="b")
ax.set_title(r'$\breve{i}\bar{A}\tilde{n}\hat{O}'
             r'\ddot{o}\acute{e}\grave{e}\vec{q}$', fontsize=20)
ax.set_xlabel("Etiqueta x")
ax.set_ylabel('Etiqueta y')
ax.text(0.2, 0.8, 'Texto rotado', rotation=45)
ax.text(0.4, 0.2, 'Texto dentro imagen')
plt.legend()

plt.show()

# %% [markdown]
# **GRÁFICOS ESTADÍSTICOS**
#
# Se van a realizar algunos gráficos estadísticos importantes para el análisis de datos

# %% [markdown]
# **GRÁFICOS DE DISPERSIÓN***
#
# Los gráficos de dispersión se usan para poner puntos de datos relacionados con los ejes horizontal y vertical. Estos gráficos se usan para analizar si existe algún tipo de correlacion entre variables.

# %%
#Se defien un rango de números desde el 0 hasta e 36
x = range(0,36)
print(x)
y=np.sin(x)

#Se usa la función plt.scatter
plt.scatter(x, y, marker='D', s=100)

plt.title('Scatterplot de la función sen(x)')
plt.xlabel('x')
plt.ylabel('y=Sen(x)')
# Out:
# range(0, 36)
# Text(0, 0.5, 'y=Sen(x)')

# %% [markdown]
# **GRÁFICO DE BARRAS**
#
# Los gráfico de barras resumen un conjunto de datos por categorías. Lo cual se ve por la altura de cada barra.

# %%
x = [1,2,3,4,5] #posibles valores
print(x)
print(type(x))
y = [0,0,6,7,9] #altura de cada barra

#Se usa plt.bar
plt.bar(x, y, label='Barras',color='green') 

#Se ponen etiquetas en el título y en los ejes
plt.xlabel('valores de x')
plt.ylabel('Frecuecias absolutas')

#Se coloca el título en el gráfico de barras
plt.title('Gráfico barras')
#Esta función permite visualizar una etiqueta en la gráfica
plt.legend()
plt.show()
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %% [markdown]
# ***VARIOS GRÁFICOS DE BARRAS**
#
# Se pueden construir gráficos de barras que permitan analizar más de una categoría para las diferentes variables cualitativas o categóricas.

# %%
#Se asignan los valores para x e y 
#Esto se hace a traves de listas como en este caso 
x = [1, 3, 5, 7, 9]
y = [5, 0, 0, 17, 9]

#De manera análoga para x2 e y2 
x2 = [2, 4, 6, 8, 10]
y2 = [15, 0, 7, 9, 0]

#Ahora se construyen las gráficas con plt.bar
#Para la primera variable
plt.bar(x,y,label='Variable 1',color='aquamarine')
#Para la segunda variable
plt.bar(x2, y2, label='Variable 2',color="green")

#Ahora se van a aponer las etiquetas sobre los gráficos
plt.xlabel('X Label (Plot Number)')
plt.ylabel('Y Label (The Data)')
 
plt.title('My Cool Graph')
plt.legend()
plt.show()

# %% [markdown]
# **GRÁFICOS DE BARRAS CON DIVISIONES**
#
# Si se quieren hacer gráficos de barras teniendo en cuenta divisiones dentro de los grupos, podemos utilizar los siguiente:

# %%
#Se define el objeto labels como una lista de caracteres
labels=['curso 1','curso 2','curso 3']
print(labels)
#Se tienen los siguientes vectores
total_20_mas = [5,20,15]
total_20_menos = [40,5,38]

sd_20_mas = [3,6,8]
sd_20_menos = [12,14,11]
width = 0.35  
#Se construye los ejes para los gráficos 
fig, ax = plt.subplots()

ax.bar(labels, total_20_mas, width, yerr=sd_20_mas, bottom=total_20_menos, label='total_20_mas')
ax.bar(labels, total_20_menos, width, yerr=sd_20_menos, 
       label='total_20_menos')

ax.set_ylabel('Total personas')
ax.set_title('Total personas grupo y edad')
ax.legend()

plt.show()
# Out:
# ['curso 1', 'curso 2', 'curso 3']

# %% [markdown]
# También se puede ver en este ejemlo con 2 variables

# %%
labels = ['Curso1', 'Curso2', 'Curso3']
total_20_mas = [5,20,15]
total_20_menos = [40,5,38]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, total_20_mas, width, label='20Mas')
rects2 = ax.bar(x + width/2, total_20_menos, width, label='20Menos')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total personas')
ax.set_title('Total personas grupo y edad')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ***HISTORAMAS***
#
# Los histogramas son un gráfico en el que se ve la distribución de frecuencia ya sea relativa o absoluta de una variable cuantitativa. La altura de cada barra representa la frecuencia absoluta o relativa observada.

# %%
#Se definen los puntajes con sus respectivas frecuencias absolutas
puntaje=[102,455,326,9,22,45,378,338,556,111,224,422,305]
bins= [0,100,200,300,400,500]

#Se construye el gráfico 
plt.hist(puntaje, bins, histtype='bar', rwidth=0.7)

#Se definen las etiquetas de cada eje junto con el título 
plt.xlabel('Puntajes')
plt.ylabel('Número personas')
 
plt.title('Puntajes obtenidos')

#Se muestra el gráfico
plt.show()

# %% [markdown]
# ***Generación de muestras aleatorias***
#
# Se va a generar una muestra aleatoria para construir un histograma

# %%
#Se define la semilla
np.random.seed(1234)

N_points = 10000
n_bins = 5

normal=np.random.normal(5,2)
print(normal)
# Distribución normal
#Devolver 10000 muestras de la distribución norm.esta.dar
x=np.random.randn(N_points) 
#Valor en y de cada valor en x
y = 0.4 * x + np.random.randn(10000) + 5 

#Ahora se procede a contruir los ejes
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the `bins` kwarg
#Podemos definir el número de divisones para la construcción del histograma 
axs[0].hist(x, bins=n_bins);  # bins: define el número de bins de igual ancho en el rango
#Parámetro para elegir poner una malla
plt.grid(True)
axs[1].hist(y, bins=n_bins,color='green');
# Out:
# 5.942870327464986

# %% [markdown]
# ***GRÁFICOS CIRCULARES***
#
# Los gráficos circulares se dividen en sectores;cada uno muestra el tamaño de la información relacionada. Los gráficos circulares suelen utilizarse para mostrar tamaños relativos dentro de un todo.

# %%
#Se definene los valores para las diferentes categorías de la variable cualitativa
Dias_sema = [1, 2, 3, 4, 5]
 
Terror = [8,9,0,4,5]
Comedia = [1,1,1,2,9]
Romance = [0,0,0,9,10]
Ciencia_Fic = [6,7,0,2,1]
Fantasia= [0,0,8,8,8]
#Suma de las frecuencias absolutas de cada categoría
print(sum(Terror))
print(sum(Comedia))
print(sum(Ciencia_Fic))
print(sum(Fantasia))

#Se definen los siguientes objetos
pedazos = [sum(Terror), sum(Comedia), sum(Romance), sum(Ciencia_Fic),sum(Fantasia)]
print(pedazos)
#En este caso se trata de un objeto con el total de las frecuencias absolutas de cada categoría
#Se trata así de un vector numérico con las frecuencias absolutas de  cada categoría

#Ahora se define un objeto que tiene los labels de cada categoría
marquillas = ['Terror', 'Comedia', 'Romance', 'Ciencia_Fic','Fantasía']
print(marquillas)

#Ahora usamos un gráfico de tarta o pie
plt.pie(pedazos,labels=marquillas,startangle=0,autopct='%1.1f%%')
# Out:
# 26
# 14
# 16
# 24
# [26, 14, 19, 16, 24]
# ['Terror', 'Comedia', 'Romance', 'Ciencia_Fic', 'Fantasía']
# ([<matplotlib.patches.Wedge at 0x7ffaf2abf250>,
# ...
#  [Text(0.7463603580622019, 0.808050874582326, 'Terror'),
#   Text(-0.5499999702695112, 0.9526279613277877, 'Comedia'),
#   Text(-1.0999999999999988, 5.1494716492391794e-08, 'Romance'),
#   Text(-0.4884733181410968, -0.9855931297773068, 'Ciencia_Fic'),
#   Text(0.7961074246862807, -0.759086930699889, 'Fantasía')],
#  [Text(0.40710564985211006, 0.44075502249945053, '26.3%'),
#   Text(-0.29999998378336973, 0.5196152516333387, '14.1%'),
#   Text(-0.5999999999999993, 2.808802717766825e-08, '19.2%'),
#   Text(-0.2664399917133255, -0.5375962526058037, '16.2%'),
#   Text(0.43424041346524395, -0.4140474167453939, '24.2%')])

# %% [markdown]
# ***Boxplot o diagramas de caja***
#
# Los diagramas de caja son herramientas gráficas para visualizar medidas estadísticas como la mediana, la media y los cuartiles.
#
# Gráficamente se pueden realizar cambios en algunas características en la realización de los boxplot.

# %%
#se va a fijar semilla
np.random.seed(19680801)

# Generación de datos aleatorios
#Se define el objeto spread (Muestra aleatoria)
spread = np.random.rand(50)*100
#print(spread)
#Se trata de una muestra de 50 observaciones de la normal estándar
#Pero que están multiplicados por 100

#Se define el objeto center (Muestra aleatoria)
center = np.ones(25) * 50
#Se trata de un vector de 25 unos multiplicado por 50
#print(center)
#Se define el objeto flier_high ( muestra aleatoria)
flier_high = np.random.rand(10) * 100 + 100
#Ahora se va a imprimir este resultado
#print(flier_high)
#Otra muestra con algunos valores 
flier_low = np.random.rand(10) * -100
#print(flier_low)
#Se construye un dataframe concatenando las muestras
data = np.concatenate((spread, center, flier_high, flier_low))
print(data)
# Out:
# [ 70.03673039  74.27508094  70.92800107  56.67455225  97.77853328
#   70.6334846   24.79157587  15.78833509  69.76985214  71.99566667
#   25.77444303  34.15467831  96.87611677  69.45070978  46.63832593
#   70.28126954  51.1785874   92.874137    73.97692989  62.24390337
#   65.15454689  39.68076115  54.32393949  79.98995282  72.15447266
#   29.53639811  16.09458806  20.61255148  13.43253868  48.06050174
#   34.25218134  36.29692901  97.29176387  11.09436116  38.82640891
#   78.30658753  97.28972601  48.32096053  33.64211054  56.74190362
#    4.79415097  38.8937029   90.63036451  16.10182093  74.36211347
#   63.29741618  32.41800177  92.23765324  23.72264387  82.39455709
#   50.          50.          50.          50.          50.
#   50.          50.          50.          50.          50.
#   50.          50.          50.          50.          50.
#   50.          50.          50.          50.          50.
#   50.          50.          50.          50.          50.
# ...

# %%
#Ahora se construye lo ejes
fig, axs = plt.subplots(2, 3) # 2 filas y 3 columnas

# Box-plot básico
axs[0, 0].boxplot(data)
axs[0, 0].set_title('Box-plot básico')

# notched plot
axs[0, 1].boxplot(data, 1)
axs[0, 1].set_title('gráfico con muesca')

# Cambiar carateristicas outliers
axs[0, 2].boxplot(data, 0, 'rD') #r=red
axs[0, 2].set_title('Cambiar carateristicas outliers')

# No mostrar outliers
axs[1, 0].boxplot(data, 0, '')
axs[1, 0].set_title("No mostrar outliers")

# Cajas horizontales
axs[1, 1].boxplot(data, 0, 'bs', 0)
axs[1, 1].set_title('Cajas horizontales')

# Cambiar tamaño bigotes
axs[1, 2].boxplot(data, 0, 'bs', 0, 0.75)
axs[1, 2].set_title('change whisker length')

#Ajuste de los subplots
fig.subplots_adjust(left=0.08, right=0.98, bottom=0.05, top=0.9,
                    hspace=0.4, wspace=0.3)
plt.show()

# %% [markdown]
# También se pueden hacer varios boxplot en un sólo gráfico

# %%
#Primer grupo de datos aleatorios generados
np.random.seed(1)
spread = np.random.rand(30) * 70
center = np.ones(25) * 50
flier_high = np.random.rand(30) * 70 + 100
flier_low = np.random.rand(10) * -100
data1 = np.concatenate((spread, center, flier_high, flier_low))
#print(data1)

# Más realizaciones de datos generados
spread = np.random.rand(50) * 100
center = np.ones(25) * 40
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
d2 = np.concatenate((spread, center, flier_high, flier_low))
print(d2)

data_2=[data1, d2, d2[::2]]
d2[::2]

# Multiples box-plot con mismos ejes
fig, ax = plt.subplots()
ax.boxplot(data_2)
plt.show()
# Out:
# [ 90.34019153  13.74747041  13.92763473  80.73912887  39.7676837
#   16.53541971  92.75085804  34.77658597  75.08121031  72.59979854
#   88.33060912  62.36722071  75.0942434   34.8898342   26.99278918
#   89.58862182  42.80911899  96.48400471  66.34414978  62.16957202
#   11.4745973   94.94892587  44.99121335  57.83896144  40.81368028
#   23.70269802  90.33795206  57.36794867   0.2870327   61.71449136
#   32.66449018  52.70581023  88.59420993  35.726976    90.85351509
#   62.33601158   1.58212428  92.94372337  69.08969175  99.73228505
#   17.23405083  13.71357496  93.2595463   69.68181615   6.60001727
#   75.54630526  75.38761885  92.30245355  71.15247586  12.4270962
#   40.          40.          40.          40.          40.
#   40.          40.          40.          40.          40.
#   40.          40.          40.          40.          40.
#   40.          40.          40.          40.          40.
#   40.          40.          40.          40.          40.
# ...

# %% [markdown]
# **DENSIDADES**
#
# La función de densidad, es la probabilidad de que la variable aleatoria caiga en una región específica del espacio de posibilidades

# %%
#Se define el conjunto de observaciones
data= [1,1,1,3,3,3,3,4,5,6,7,8,8,8,8,9,5,55,6,9,8,7]
#Se define el objeto density
density = kde.gaussian_kde(data) #Método de estimación kernel usando un kernel Gaussiano
#Se define el rango de x y la malla
x = np.linspace(-2,13,300)
#Se pone  a y en término de x
y=density(x)
#gráfica de la densidad
plt.plot(x,y)

plt.title("Density Plot of the data")
plt.show()

# %% [markdown]
# En la gráfica de densidad anterior, el ancho de banda es automático, generando así que la figura no sea lo suficientemente precisa. Entonces, para establecer el ancho de banda, podemos usar la función covariance_factor y usar el método _compute_covariance para que todos los factores se calculen correctamente para generar el gráfico preciso.

# %%
#Se define el conjunto de datos
data_1 = [1,1,1,1,1,3,3,3,3,4,5,6,7,8,8,8,8,9,5,55,5,5,6]
#Se usa el método de estimación kernel gaussiano
prob_density = kde.gaussian_kde(data_1)
#Se establece un nuevo ancho de banda para la estimación kernel 
prob_density.covariance_factor = lambda : .25
prob_density._compute_covariance()

x = np.linspace(-2,10,300)
y=prob_density(x)

plt.plot(x,y)
plt.title("Density Plot of the data")
plt.show()

# %% [markdown]
# **Otra manera de graficar densidades**

# %%
#Primero se define el conjunto de datos o vector de observaciones
data = [1,1,1,1,1,3,3,3,3,4,5,6,7,8,8,8,8,9,5,55,5,5,6]
#Se usa la función pd.DataFrame(data).plot(kind='density')
pd.DataFrame(data).plot(kind='density')
plt.title('gráfica de densidad del conjunto de datos')
plt.show()

# %% [markdown]
# Por otro lado, también se puede también realizar gráficos de densidades e histogramas conjuntamente, además de modificar que se realice vertical u horizontalmente.

# %%
#sns.set_theme()
np.random.seed(1212) #generar numeros aletorios
x = np.random.randn(100)
print(x)
#De la ibrería seaborn (sns) se usa sns.distplot(x)
ax = sns.distplot(x,color='blue')
# Out:
# [ 7.37352073e-01 -6.17297117e-01  4.62930361e-01 -3.44190280e-01
#   9.79563523e-01 -9.49642143e-01 -8.20336885e-01  8.17264634e-01
#  -1.59057847e-01  1.04330464e-01 -2.21350088e-01  3.07270992e-01
#  -4.41273599e-01  1.22892765e+00 -1.81467041e+00  3.61945716e-01
#   1.42909007e-02  1.15003788e+00 -9.65656859e-01  1.12216294e+00
#  -7.86390941e-01 -5.83331889e-01  1.15586364e+00 -9.22801238e-01
#  -6.70625420e-02  8.94725444e-01 -3.20221225e-01 -5.28666902e-01
#  -4.12712355e-02 -7.35591798e-01  5.02020640e-01 -8.42569266e-01
#   4.80121154e-01  1.15138091e+00  1.02741644e+00 -1.12996896e+00
#  -5.46331652e-01 -1.22396759e+00  1.12084893e+00  3.94901447e-01
#   9.35378541e-01 -1.90238930e+00 -9.59185990e-01 -6.98342522e-01
#   1.16357454e-02  1.81935831e+00 -4.40961997e-01 -6.19281648e-01
#   6.38275087e-01  3.16093131e-01 -4.02091635e-01  6.18323528e-01
#  -5.98543036e-02  8.93016994e-02  1.63610325e+00 -1.78240532e+00
# ...

# %%
sns.set_color_codes()
x= [1,2,3,3,4,4,5,5,5,6,6,7,7,8,9]
ax = sns.distplot(x, color="red",vertical=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot(x, rug=True, hist=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **ACTIVIDADES**
#
#
#
# *   Dibuje 3 funciones distintas, cada una con un color y marca diferente, además de una leyenda para poder diferenciarlas.
# *   Haga dos densidades diferentes y grafiquelas como subplots, generando una columna y dos filas de una leyenda para poder diferenciarlas.
# * Suponga una situación en la que tiene datos catégoricos con 3 categorías. Gráfique y use leyendas para un diagrama de barras, un gráfico circular con los porcentajes y multiples box-plot con mismos ejes. *Realice una muestra aleatoria de datos y grafique un boxplot que tenga como puntos outliers de color amarillo y los bigotes recortados. Además guarde la imagen en formato .jpeg

# %% [markdown]
# **SOLUCIÓN**
#
#  a) se van a hacer las gráficas de las siguientes funciones:
#
# $f(x)=e^{-x}$,  $g(x)=\sqrt{x}$ y $h(x)=cos^2(x)$
#
# Las instrucciones en python se presentan a continuación

# %%
#Se van a definir los valores de x
x=np.linspace(0,10,100)
#Se define la función exp(x) desde numpy
y=np.exp(-x)

w=(np.cos(x))**2
#Se grafica la función
plt.plot(x,y,label='$f(x)=e^{-x}$',color='blue')


plt.xlabel('Valores de x')

plt.title('gráficas de $f(x)=e^{-x}$')
ax.plot(range(10),label="$f(x)=e^{-x}$")
plt.legend()
plt.show()

# %%
#Ahora se define sqrt(x)
z=np.sqrt(x)
#Se grafica la función
plt.plot(x,z,label='$g(x)=\sqrt{x}$',color='green')
#label de x
plt.xlabel('Valores de x')
#Se define el título del gráfico
plt.title('Gráfica de $g(x)=\sqrt{x}$')
plt.legend()
plt.show()

# %%
#Finalmente se define cos^2(x)
w=(np.cos(x))**2

#Se grafica la función
plt.plot(x,w,label='$h(x)=cos^2(x)$',color='red')
#label de x
plt.xlabel('Valores de x')
#Se define el título del gráfico
plt.title('Gráfica de $h(x)=cos^{2}(x)$')
plt.legend()
plt.show()

# %% [markdown]
# b) **SOLUCIÓN**
#
# primero se va a fijar la semilla y después generar muestras aleatorias de la distribución exponencial y después de la normal estpandar. las gráficas obtenidas se van a diagramar en un una matiz de gráficas con una columna y dos filas.Estos resultados se presentan a continuación

# %%
from numpy.core.fromnumeric import size
#Primero se fija la semilla
np.random.seed(15753)

x=np.linspace(-2,2,1000)
#Ahora se generan las muestras de la distribución exponencial
m1=np.random.uniform(0,1,1000)
#Se imprimen la muestra de tamaño 1000
density1=kde.gaussian_kde(m1)
z2=density1(x)
#ahora vamos a graficar la función


#En este punto se va a construir la muestra de la distribución normal estándar
m2=np.random.randn(1000)
density2= kde.gaussian_kde(m2)

y=density2(x)

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x,z2)
plt.subplot(2, 1, 2)
plt.plot(x,y)
plt.show()
